# %%
import nibabel as nib
import numpy as np

def read_nii_header(nii_file_path):
    """
    读取nii.gz格式CT图像的头部信息
    :param nii_file_path: nii.gz文件的路径（绝对路径/相对路径）
    :return: 无返回值，直接打印头部信息
    """
    try:
        # 1. 加载nii.gz文件
        img = nib.load(nii_file_path)
        
        # 2. 获取头部信息对象
        header = img.header
        
        # 3. 打印完整的头部信息（原始格式）
        print("=" * 50)
        print("完整的CT图像头部信息：")
        print("=" * 50)
        print(header)
        
        # 4. 提取并打印常用的关键头部信息（更易读）
        print("\n" + "=" * 50)
        print("关键头部信息（整理后）：")
        print("=" * 50)
        # 图像维度（高度、宽度、层数）
        print(f"图像维度 (H, W, D): {header.get_data_shape()}")
        # 体素大小（每个体素的物理尺寸，单位：mm）
        print(f"体素大小 (x, y, z) (mm): {header.get_zooms()}")
        # 数据类型（如int16、float32）
        print(f"数据类型: {header.get_data_dtype()}")
        # 像素值范围（需结合图像数据）
        data = img.get_fdata()
        print(f"像素值范围: 最小值={np.min(data):.2f}, 最大值={np.max(data):.2f}, 均值={np.mean(data):.2f}")
        # 空间方向矩阵（描述图像的空间朝向）
        print(f"空间方向矩阵:\n{img.affine[:3, :3]}")
        # 图像原点（空间坐标原点）
        print(f"图像原点 (x, y, z): {img.affine[:3, 3]}")
        # 切片厚度（z轴方向的体素大小）
        print(f"切片厚度 (mm): {header.get_zooms()[2]}")
        
    except FileNotFoundError:
        print(f"错误：未找到文件 {nii_file_path}，请检查文件路径是否正确！")
    except Exception as e:
        print(f"读取文件时出错：{str(e)}")

# ---------------------- 调用示例 ----------------------
if __name__ == "__main__":
    # 替换为你的nii.gz文件路径
    nii_file_path = "/home/user512-003/songcw/data/naochuxue/image/0c62321b92.nii.gz"  # 例如："D:/data/ct_scan.nii.gz"
    read_nii_header(nii_file_path)
# Out:
# ==================================================
# 完整的CT图像头部信息：
# ==================================================
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : np.bytes_(b'')
# db_name         : np.bytes_(b'')
# extents         : 0
# session_error   : 0
# regular         : np.bytes_(b'r')
# dim_info        : 0
# dim             : [  3 512 512  32   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [1.        0.488281  0.488281  5.4313226 0.        0.        0.
#  0.       ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 2
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : np.bytes_(b'')
# aux_file        : np.bytes_(b'')
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.0
# quatern_c       : -0.19936785
# quatern_d       : 0.97992474
# qoffset_x       : 125.0
# qoffset_y       : 121.763
# qoffset_z       : -34.565
# srow_x          : [ -0.488281   0.         0.       125.      ]
# srow_y          : [  0.          -0.44946507  -2.122186   121.763     ]
# srow_z          : [  0.          -0.19078651   4.9995594  -34.565     ]
# intent_name     : np.bytes_(b'')
# magic           : np.bytes_(b'n+1')
#
# ==================================================
# 关键头部信息（整理后）：
# ==================================================
# 图像维度 (H, W, D): (512, 512, 32)
# 体素大小 (x, y, z) (mm): (np.float32(0.488281), np.float32(0.488281), np.float32(5.4313226))
# 数据类型: int32
# 像素值范围: 最小值=0.00, 最大值=80.00, 均值=10.53
# 空间方向矩阵:
# [[-0.48828101  0.          0.        ]
#  [ 0.         -0.44946507 -2.12218595]
#  [ 0.         -0.19078651  4.9995594 ]]
# 图像原点 (x, y, z): [125.         121.76300049 -34.56499863]
# 切片厚度 (mm): 5.4313225746154785

# %%
import nibabel as nib
import numpy as np

def read_nii_header_with_manufacturer(nii_file_path):
    """
    读取nii.gz格式CT图像的头部信息，重点提取设备制造商信息
    :param nii_file_path: nii.gz文件的路径（绝对路径/相对路径）
    :return: 无返回值，直接打印头部信息及制造商
    """
    try:
        # 1. 加载nii.gz文件
        img = nib.load(nii_file_path)
        header = img.header
        
        # 2. 提取制造商相关信息（检查多个常见字段）
        print("=" * 60)
        print("CT扫描设备制造商信息：")
        print("=" * 60)
        
        # 定义需要检查的制造商相关字段（按优先级排序）
        manufacturer_fields = [
            'manufacturer',
            'vendor_name',
            'manufacturer_model_name',
            'device_id',
            'institution_name'
        ]
        
        found = False
        for field in manufacturer_fields:
            # 不同nibabel版本获取字段的方式兼容
            if hasattr(header, 'get'):
                value = header.get(field, "未找到该字段")
            else:
                value = header[field] if field in header else "未找到该字段"
            
            # 过滤空值/无效值
            if value not in ["", "未找到该字段", b'', None]:
                print(f"【{field}】: {value}")
                found = True
        
        if not found:
            print("⚠️  未在头部信息中找到明确的制造商信息（部分设备可能未写入该字段）")
        
        # 3. 保留之前的关键头部信息（可选，方便对照）
        print("\n" + "=" * 60)
        print("核心头部信息（参考）：")
        print("=" * 60)
        print(f"图像维度 (H, W, D): {header.get_data_shape()}")
        print(f"体素大小 (x, y, z) (mm): {header.get_zooms()}")
        print(f"数据类型: {header.get_data_dtype()}")
        
    except FileNotFoundError:
        print(f"错误：未找到文件 {nii_file_path}，请检查文件路径是否正确！")
    except Exception as e:
        print(f"读取文件时出错：{str(e)}")

# ---------------------- 调用示例 ----------------------
if __name__ == "__main__":
    # 替换为你的nii.gz文件路径
    nii_file_path = "/home/user512-003/songcw/data/naochuxue/image/0c62321b92.nii.gz" # 例如："D:/data/ct_scan.nii.gz"
    read_nii_header_with_manufacturer(nii_file_path)
# Out:
# ============================================================
# CT扫描设备制造商信息：
# ============================================================
# ⚠️  未在头部信息中找到明确的制造商信息（部分设备可能未写入该字段）
#
# ============================================================
# 核心头部信息（参考）：
# ============================================================
# 图像维度 (H, W, D): (512, 512, 32)
# 体素大小 (x, y, z) (mm): (np.float32(0.488281), np.float32(0.488281), np.float32(5.4313226))
# 数据类型: int32

# %%
import nibabel as nib
import numpy as np

def calculate_hemorrhage_volume(label_path, image_path=None):
    """
    基于分割掩码计算出血体积
    :param label_path: 出血分割掩码文件路径（label.nii.gz）
    :param image_path: 原CT图像路径（image.nii.gz，可选，若掩码头部信息完整可省略）
    :return: 出血体积（mm³）、出血体积（cm³）、单个体素体积（mm³）、出血体素数
    """
    try:
        # 1. 加载分割掩码文件
        label_img = nib.load(label_path)
        label_data = label_img.get_fdata()  # 获取掩码数据（三维数组）
        label_header = label_img.header

        # 2. 验证/获取体素尺寸（优先用掩码的头部信息，若缺失则用原图像）
        if image_path is not None:
            img = nib.load(image_path)
            # 检查掩码和原图像的维度是否一致（避免空间不匹配）
            if label_data.shape != img.get_fdata().shape:
                raise ValueError(f"掩码维度{label_data.shape}与原图像维度{img.get_fdata().shape}不一致！")
            voxel_sizes = img.header.get_zooms()  # (x, y, z) 单位：mm
        else:
            voxel_sizes = label_header.get_zooms()

        # 3. 计算单个体素的体积（mm³）
        voxel_volume = voxel_sizes[0] * voxel_sizes[1] * voxel_sizes[2]

        # 4. 统计出血区域的体素数（掩码中非0值即为出血区域）
        hemorrhage_voxels = np.count_nonzero(label_data)

        # 5. 计算总出血体积
        hemorrhage_volume_mm3 = hemorrhage_voxels * voxel_volume
        hemorrhage_volume_cm3 = hemorrhage_volume_mm3 / 1000  # 转换为cm³（1 cm³ = 1000 mm³）

        # 打印结果（直观展示）




        
        print("=" * 60)
        print("出血体积计算结果：")
        print("=" * 60)
        print(f"单个体素尺寸 (x, y, z): {voxel_sizes[0]:.4f} × {voxel_sizes[1]:.4f} × {voxel_sizes[2]:.4f} mm")
        print(f"单个体素体积: {voxel_volume:.4f} mm³")
        print(f"出血区域体素总数: {hemorrhage_voxels}")
        print(f"出血体积: {hemorrhage_volume_mm3:.2f} mm³ ({hemorrhage_volume_cm3:.3f} cm³)")

        return hemorrhage_volume_mm3, hemorrhage_volume_cm3, voxel_volume, hemorrhage_voxels

    except FileNotFoundError as e:
        print(f"错误：未找到文件 - {e}")
        return None, None, None, None
    except ValueError as e:
        print(f"错误：{e}")
        return None, None, None, None
    except Exception as e:
        print(f"计算出错：{str(e)}")
        return None, None, None, None

# ---------------------- 调用示例 ----------------------
if __name__ == "__main__":
    # 替换为你的文件实际路径
    label_file = "/home/user512-003/songcw/data/naochuxue/image/0c62321b92.nii.gz"    # 出血分割掩码
    image_file = "/home/user512-003/songcw/data/naochuxue/manual_label/0c62321b92.nii.gz"    # 原CT图像（可选，若掩码头部信息完整可设为None）
    
    # 调用函数计算出血体积
    calculate_hemorrhage_volume(label_file, image_file)
# Out:
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4313 mm
# 单个体素体积: 1.2949 mm³
# 出血区域体素总数: 1787231
# 出血体积: 2314333.50 mm³ (2314.333 cm³)

# %%
import nibabel as nib
import numpy as np
import pandas as pd
import os

def calculate_hemorrhage_volume(label_path, image_path=None):
    """
    基于分割掩码计算出血体积
    :param label_path: 出血分割掩码文件路径（label.nii.gz）
    :param image_path: 原CT图像路径（image.nii.gz，可选，若掩码头部信息完整可省略）
    :return: 出血体积（mm³）、出血体积（cm³）、单个体素体积（mm³）、出血体素数
    """
    try:
        # 1. 加载分割掩码文件
        label_img = nib.load(label_path)
        label_data = label_img.get_fdata()  # 获取掩码数据（三维数组）
        label_header = label_img.header

        # 2. 验证/获取体素尺寸（优先用掩码的头部信息，若缺失则用原图像）
        if image_path is not None:
            img = nib.load(image_path)
            # 检查掩码和原图像的维度是否一致（避免空间不匹配）
            if label_data.shape != img.get_fdata().shape:
                raise ValueError(f"掩码维度{label_data.shape}与原图像维度{img.get_fdata().shape}不一致！")
            voxel_sizes = img.header.get_zooms()  # (x, y, z) 单位：mm
        else:
            voxel_sizes = label_header.get_zooms()

        # 3. 计算单个体素的体积（mm³）
        voxel_volume = voxel_sizes[0] * voxel_sizes[1] * voxel_sizes[2]

        # 4. 统计出血区域的体素数（掩码中非0值即为出血区域）
        hemorrhage_voxels = np.count_nonzero(label_data)

        # 5. 计算总出血体积
        hemorrhage_volume_mm3 = hemorrhage_voxels * voxel_volume
        hemorrhage_volume_cm3 = hemorrhage_volume_mm3 / 1000  # 转换为cm³（1 cm³ = 1000 mm³）

        # 打印结果（直观展示）




        
        print("=" * 60)
        print("出血体积计算结果：")
        print("=" * 60)
        print(f"单个体素尺寸 (x, y, z): {voxel_sizes[0]:.4f} × {voxel_sizes[1]:.4f} × {voxel_sizes[2]:.4f} mm")
        print(f"单个体素体积: {voxel_volume:.4f} mm³")
        print(f"出血区域体素总数: {hemorrhage_voxels}")
        print(f"出血体积: {hemorrhage_volume_mm3:.2f} mm³ ({hemorrhage_volume_cm3:.3f} cm³)")

        return hemorrhage_volume_mm3, hemorrhage_volume_cm3, voxel_volume, hemorrhage_voxels

    except FileNotFoundError as e:
        print(f"错误：未找到文件 - {e}")
        return None, None, None, None
    except ValueError as e:
        print(f"错误：{e}")
        return None, None, None, None
    except Exception as e:
        print(f"计算出错：{str(e)}")
        return None, None, None, None


def save_volume_to_csv(data, csv_file_path):
    """
    将出血体积数据列表保存为CSV文件
    :param data: 包含file_name和hemorrhage_volume_cm3的字典列表
    :param csv_file_path: 输出CSV文件路径（如'hemorrhage_volume.csv'）
    :return: 无返回值，直接生成CSV文件
    """
    try:
        # 1. 将列表转换为DataFrame（方便处理数据类型和缺失值）
        df = pd.DataFrame(data)
        
        # 2. 处理数据类型：np.float32转普通float，None转为空字符串（CSV更易读）
        df['hemorrhage_volume_cm3'] = df['hemorrhage_volume_cm3'].apply(
            lambda x: float(x) if isinstance(x, np.float32) or isinstance(x, float) else x
        )
        
        # 3. 保存为CSV文件（index=False 不保存行索引，encoding='utf-8' 兼容中文）
        df.to_csv(csv_file_path, index=False, encoding='utf-8')
        
        print(f"✅ 数据已成功保存到CSV文件：{csv_file_path}")
        print(f"📊 数据总行数：{len(df)}")
        print(f"⚠️  缺失值数量：{df['hemorrhage_volume_cm3'].isnull().sum()}")
        
    except Exception as e:
        print(f"❌ 保存CSV时出错：{str(e)}")

# ---------------------- 调用示例 ----------------------
if __name__ == "__main__":
    # 替换为你的文件实际路径
    label_dir = "/home/user512-003/songcw/data/naochuxue/manual_label"    # 出血分割掩码
    image_dir = "/home/user512-003/songcw/data/naochuxue/image"    # 原CT图像（可选，若掩码头部信息完整可设为None）

    hemorrhage_volume_cm3_list = []
    for item in os.listdir(image_dir):
        label_file = os.path.join(label_dir, item)
        image_file = os.path.join(image_dir, item)
        # 调用函数计算出血体积
        _, hemorrhage_volume_cm3, _, _= calculate_hemorrhage_volume(label_file, image_file)
        hemorrhage_volume_cm3_list.append({"file_name":item, "hemorrhage_volume_cm3":hemorrhage_volume_cm3})
    print(hemorrhage_volume_cm3_list)
    output_csv_path = "hemorrhage_volume.csv"
    save_volume_to_csv(hemorrhage_volume_cm3_list, output_csv_path)
# Out:
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3502 mm
# 单个体素体积: 1.2756 mm³
# 出血区域体素总数: 470
# 出血体积: 599.53 mm³ (0.600 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3738 mm
# 单个体素体积: 1.2812 mm³
# 出血区域体素总数: 1630
# 出血体积: 2088.36 mm³ (2.088 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4121 × 0.4121 × 5.0000 mm
# 单个体素体积: 0.8492 mm³
# 出血区域体素总数: 7631
# 出血体积: 6480.02 mm³ (6.480 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4688 × 0.4688 × 5.0000 mm
# 单个体素体积: 1.0986 mm³
# 出血区域体素总数: 5141
# 出血体积: 5648.07 mm³ (5.648 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3508 mm
# 单个体素体积: 1.2757 mm³
# 出血区域体素总数: 1668
# 出血体积: 2127.93 mm³ (2.128 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.9766 × 0.9766 × 5.2575 mm
# 单个体素体积: 5.0139 mm³
# 出血区域体素总数: 1817
# 出血体积: 9110.30 mm³ (9.110 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.4789 mm
# 单个体素体积: 1.0679 mm³
# 出血区域体素总数: 16941
# 出血体积: 18090.49 mm³ (18.090 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4375 × 0.4375 × 5.0000 mm
# 单个体素体积: 0.9570 mm³
# 出血区域体素总数: 2903
# 出血体积: 2778.26 mm³ (2.778 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4121 × 0.4121 × 5.0000 mm
# 单个体素体积: 0.8492 mm³
# 出血区域体素总数: 332
# 出血体积: 281.92 mm³ (0.282 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1012 mm
# 单个体素体积: 1.2162 mm³
# 出血区域体素总数: 31274
# 出血体积: 38035.86 mm³ (38.036 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1025 mm
# 单个体素体积: 1.2165 mm³
# 出血区域体素总数: 6963
# 出血体积: 8470.67 mm³ (8.471 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4688 × 0.4688 × 5.0000 mm
# 单个体素体积: 1.0986 mm³
# 出血区域体素总数: 11354
# 出血体积: 12473.88 mm³ (12.474 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.1131 mm
# 单个体素体积: 0.9806 mm³
# 出血区域体素总数: 16375
# 出血体积: 16057.86 mm³ (16.058 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1530 mm
# 单个体素体积: 1.2286 mm³
# 出血区域体素总数: 455
# 出血体积: 559.00 mm³ (0.559 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2508 mm
# 单个体素体积: 1.2519 mm³
# 出血区域体素总数: 420
# 出血体积: 525.79 mm³ (0.526 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 7948
# 出血体积: 9474.75 mm³ (9.475 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2000 mm
# 单个体素体积: 1.2398 mm³
# 出血区域体素总数: 15997
# 出血体积: 19832.89 mm³ (19.833 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4949 × 0.4949 × 5.0000 mm
# 单个体素体积: 1.2244 mm³
# 出血区域体素总数: 1095
# 出血体积: 1340.77 mm³ (1.341 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4590 × 0.4590 × 5.0000 mm
# 单个体素体积: 1.0533 mm³
# 出血区域体素总数: 62749
# 出血体积: 66095.61 mm³ (66.096 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.0489 mm
# 单个体素体积: 0.9653 mm³
# 出血区域体素总数: 547
# 出血体积: 528.03 mm³ (0.528 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4824 × 0.4824 × 5.2275 mm
# 单个体素体积: 1.2166 mm³
# 出血区域体素总数: 616
# 出血体积: 749.43 mm³ (0.749 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.5449 × 0.5449 × 5.0502 mm
# 单个体素体积: 1.4996 mm³
# 出血区域体素总数: 26118
# 出血体积: 39166.50 mm³ (39.167 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.6836 × 0.6836 × 6.0000 mm
# 单个体素体积: 2.8038 mm³
# 出血区域体素总数: 7079
# 出血体积: 19848.12 mm³ (19.848 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 28428
# 出血体积: 34792.82 mm³ (34.793 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.1227 mm
# 单个体素体积: 0.9829 mm³
# 出血区域体素总数: 7395
# 出血体积: 7268.66 mm³ (7.269 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 6.3252 mm
# 单个体素体积: 1.5080 mm³
# 出血区域体素总数: 30676
# 出血体积: 46260.92 mm³ (46.261 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1887 mm
# 单个体素体积: 1.2371 mm³
# 出血区域体素总数: 2639
# 出血体积: 3264.69 mm³ (3.265 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1315 mm
# 单个体素体积: 1.2234 mm³
# 出血区域体素总数: 18233
# 出血体积: 22307.12 mm³ (22.307 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.1034 mm
# 单个体素体积: 0.9783 mm³
# 出血区域体素总数: 150
# 出血体积: 146.75 mm³ (0.147 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3925 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 32470
# 出血体积: 41745.86 mm³ (41.746 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.6387 × 0.6387 × 6.0000 mm
# 单个体素体积: 2.4474 mm³
# 出血区域体素总数: 1773
# 出血体积: 4339.26 mm³ (4.339 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3925 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 246
# 出血体积: 316.28 mm³ (0.316 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4949 × 0.4949 × 5.0000 mm
# 单个体素体积: 1.2244 mm³
# 出血区域体素总数: 7431
# 出血体积: 9098.87 mm³ (9.099 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3562 mm
# 单个体素体积: 1.2770 mm³
# 出血区域体素总数: 59211
# 出血体积: 75613.32 mm³ (75.613 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4609 × 0.4609 × 5.0000 mm
# 单个体素体积: 1.0623 mm³
# 出血区域体素总数: 590
# 出血体积: 626.77 mm³ (0.627 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4648 × 0.4648 × 5.0000 mm
# 单个体素体积: 1.0804 mm³
# 出血区域体素总数: 17222
# 出血体积: 18606.62 mm³ (18.607 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3502 mm
# 单个体素体积: 1.2756 mm³
# 出血区域体素总数: 15741
# 出血体积: 20078.96 mm³ (20.079 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0774 mm
# 单个体素体积: 1.2106 mm³
# 出血区域体素总数: 2878
# 出血体积: 3483.98 mm³ (3.484 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 254
# 出血体积: 302.79 mm³ (0.303 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0695 mm
# 单个体素体积: 1.2087 mm³
# 出血区域体素总数: 1519
# 出血体积: 1835.95 mm³ (1.836 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4317 mm
# 单个体素体积: 1.2950 mm³
# 出血区域体素总数: 3916
# 出血体积: 5071.33 mm³ (5.071 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.0966 mm
# 单个体素体积: 0.9767 mm³
# 出血区域体素总数: 2415
# 出血体积: 2358.77 mm³ (2.359 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 10541
# 出血体积: 12565.84 mm³ (12.566 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.7737 mm
# 单个体素体积: 1.3766 mm³
# 出血区域体素总数: 22811
# 出血体积: 31400.85 mm³ (31.401 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.5488 × 0.5488 × 6.3010 mm
# 单个体素体积: 1.8979 mm³
# 出血区域体素总数: 2555
# 出血体积: 4849.21 mm³ (4.849 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4570 × 0.4570 × 5.0000 mm
# 单个体素体积: 1.0444 mm³
# 出血区域体素总数: 5658
# 出血体积: 5909.15 mm³ (5.909 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4336 × 0.4336 × 5.0000 mm
# 单个体素体积: 0.9400 mm³
# 出血区域体素总数: 26868
# 出血体积: 25256.40 mm³ (25.256 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 2471
# 出血体积: 3024.24 mm³ (3.024 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0375 mm
# 单个体素体积: 1.2010 mm³
# 出血区域体素总数: 255
# 出血体积: 306.26 mm³ (0.306 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 1343
# 出血体积: 1643.69 mm³ (1.644 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 18186
# 出血体积: 22257.71 mm³ (22.258 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4375 × 0.4375 × 5.0000 mm
# 单个体素体积: 0.9570 mm³
# 出血区域体素总数: 2059
# 出血体积: 1970.53 mm³ (1.971 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2013 mm
# 单个体素体积: 1.2401 mm³
# 出血区域体素总数: 875
# 出血体积: 1085.07 mm³ (1.085 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 442
# 出血体积: 540.96 mm³ (0.541 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1313 mm
# 单个体素体积: 1.2234 mm³
# 出血区域体素总数: 10850
# 出血体积: 13273.79 mm³ (13.274 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 6.2527 mm
# 单个体素体积: 1.4908 mm³
# 出血区域体素总数: 548
# 出血体积: 816.93 mm³ (0.817 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1420 mm
# 单个体素体积: 1.2259 mm³
# 出血区域体素总数: 2729
# 出血体积: 3345.61 mm³ (3.346 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 1108
# 出血体积: 1320.84 mm³ (1.321 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3515 mm
# 单个体素体积: 1.2759 mm³
# 出血区域体素总数: 22066
# 出血体积: 28153.79 mm³ (28.154 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3502 mm
# 单个体素体积: 1.2756 mm³
# 出血区域体素总数: 8577
# 出血体积: 10940.71 mm³ (10.941 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1004 mm
# 单个体素体积: 1.2160 mm³
# 出血区域体素总数: 2003
# 出血体积: 2435.71 mm³ (2.436 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1420 mm
# 单个体素体积: 1.2259 mm³
# 出血区域体素总数: 47699
# 出血体积: 58476.45 mm³ (58.476 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0775 mm
# 单个体素体积: 1.2106 mm³
# 出血区域体素总数: 12384
# 出血体积: 14991.54 mm³ (14.992 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3212 mm
# 单个体素体积: 1.2687 mm³
# 出血区域体素总数: 28661
# 出血体积: 36361.55 mm³ (36.362 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4766 × 0.4766 × 5.0000 mm
# 单个体素体积: 1.1356 mm³
# 出血区域体素总数: 15737
# 出血体积: 17870.29 mm³ (17.870 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4434 × 0.4434 × 3.7500 mm
# 单个体素体积: 0.7371 mm³
# 出血区域体素总数: 1199
# 出血体积: 883.82 mm³ (0.884 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 3.7500 mm
# 单个体素体积: 0.8941 mm³
# 出血区域体素总数: 3458
# 出血体积: 3091.69 mm³ (3.092 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0850 mm
# 单个体素体积: 1.2124 mm³
# 出血区域体素总数: 11570
# 出血体积: 14027.01 mm³ (14.027 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 6.0528 mm
# 单个体素体积: 1.4431 mm³
# 出血区域体素总数: 15018
# 出血体积: 21672.30 mm³ (21.672 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3927 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 8574
# 出血体积: 11023.84 mm³ (11.024 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3230 mm
# 单个体素体积: 1.2691 mm³
# 出血区域体素总数: 3736
# 出血体积: 4741.39 mm³ (4.741 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.2828 mm
# 单个体素体积: 1.0211 mm³
# 出血区域体素总数: 297
# 出血体积: 303.26 mm³ (0.303 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0512 mm
# 单个体素体积: 1.2043 mm³
# 出血区域体素总数: 8260
# 出血体积: 9947.60 mm³ (9.948 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 7061
# 出血体积: 8417.37 mm³ (8.417 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0488 mm
# 单个体素体积: 1.2037 mm³
# 出血区域体素总数: 8838
# 出血体积: 10638.48 mm³ (10.638 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0515 mm
# 单个体素体积: 1.2044 mm³
# 出血区域体素总数: 5235
# 出血体积: 6304.89 mm³ (6.305 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2573 mm
# 单个体素体积: 1.2534 mm³
# 出血区域体素总数: 3162
# 出血体积: 3963.34 mm³ (3.963 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.0167 mm
# 单个体素体积: 0.9577 mm³
# 出血区域体素总数: 71618
# 出血体积: 68585.45 mm³ (68.585 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0488 mm
# 单个体素体积: 1.2037 mm³
# 出血区域体素总数: 8747
# 出血体积: 10528.94 mm³ (10.529 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 6.0000 mm
# 单个体素体积: 1.4305 mm³
# 出血区域体素总数: 2437
# 出血体积: 3486.16 mm³ (3.486 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.3887 × 0.3887 × 5.0000 mm
# 单个体素体积: 0.7553 mm³
# 出血区域体素总数: 502
# 出血体积: 379.18 mm³ (0.379 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.2829 mm
# 单个体素体积: 1.0211 mm³
# 出血区域体素总数: 13314
# 出血体积: 13595.21 mm³ (13.595 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4668 × 0.4668 × 5.0000 mm
# 单个体素体积: 1.0895 mm³
# 出血区域体素总数: 5279
# 出血体积: 5751.45 mm³ (5.751 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 13199
# 出血体积: 16154.16 mm³ (16.154 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4937 mm
# 单个体素体积: 1.3098 mm³
# 出血区域体素总数: 3706
# 出血体积: 4854.12 mm³ (4.854 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.2278 mm
# 单个体素体积: 1.0080 mm³
# 出血区域体素总数: 37897
# 出血体积: 38199.33 mm³ (38.199 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 36361
# 出血体积: 43345.69 mm³ (43.346 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4375 × 0.4375 × 5.0000 mm
# 单个体素体积: 0.9570 mm³
# 出血区域体素总数: 14324
# 出血体积: 13708.52 mm³ (13.709 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.0968 mm
# 单个体素体积: 0.9768 mm³
# 出血区域体素总数: 1440
# 出血体积: 1406.54 mm³ (1.407 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1650 mm
# 单个体素体积: 1.2314 mm³
# 出血区域体素总数: 484
# 出血体积: 596.01 mm³ (0.596 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.4888 mm
# 单个体素体积: 1.0702 mm³
# 出血区域体素总数: 17548
# 出血体积: 18780.20 mm³ (18.780 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4313 mm
# 单个体素体积: 1.2949 mm³
# 出血区域体素总数: 40746
# 出血体积: 52763.09 mm³ (52.763 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3515 mm
# 单个体素体积: 1.2759 mm³
# 出血区域体素总数: 839
# 出血体积: 1070.47 mm³ (1.070 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 14015
# 出血体积: 16707.17 mm³ (16.707 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 2515
# 出血体积: 2998.11 mm³ (2.998 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3212 mm
# 单个体素体积: 1.2687 mm³
# 出血区域体素总数: 21315
# 出血体积: 27041.71 mm³ (27.042 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.3945 × 0.3945 × 5.0000 mm
# 单个体素体积: 0.7783 mm³
# 出血区域体素总数: 29086
# 出血体积: 22636.89 mm³ (22.637 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1004 mm
# 单个体素体积: 1.2160 mm³
# 出血区域体素总数: 300
# 出血体积: 364.81 mm³ (0.365 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 9464
# 出血体积: 11281.96 mm³ (11.282 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1004 mm
# 单个体素体积: 1.2160 mm³
# 出血区域体素总数: 402
# 出血体积: 488.84 mm³ (0.489 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 1881
# 出血体积: 2242.32 mm³ (2.242 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 4379
# 出血体积: 5220.17 mm³ (5.220 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 1446
# 出血体积: 1769.75 mm³ (1.770 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 4120
# 出血体积: 5042.44 mm³ (5.042 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1649 mm
# 单个体素体积: 1.2314 mm³
# 出血区域体素总数: 8857
# 出血体积: 10906.66 mm³ (10.907 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2068 mm
# 单个体素体积: 1.2414 mm³
# 出血区域体素总数: 19710
# 出血体积: 24468.04 mm³ (24.468 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2147 mm
# 单个体素体积: 1.2433 mm³
# 出血区域体素总数: 4839
# 出血体积: 6016.28 mm³ (6.016 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0695 mm
# 单个体素体积: 1.2087 mm³
# 出血区域体素总数: 9474
# 出血体积: 11450.90 mm³ (11.451 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3738 mm
# 单个体素体积: 1.2812 mm³
# 出血区域体素总数: 1212
# 出血体积: 1552.82 mm³ (1.553 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 11207
# 出血体积: 13359.77 mm³ (13.360 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4355 × 0.4355 × 5.4733 mm
# 单个体素体积: 1.0383 mm³
# 出血区域体素总数: 1991
# 出血体积: 2067.22 mm³ (2.067 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3925 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 972
# 出血体积: 1249.68 mm³ (1.250 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4949 × 0.4949 × 5.0000 mm
# 单个体素体积: 1.2244 mm³
# 出血区域体素总数: 131
# 出血体积: 160.40 mm³ (0.160 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.3131 mm
# 单个体素体积: 1.0283 mm³
# 出血区域体素总数: 3850
# 出血体积: 3959.08 mm³ (3.959 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4785 × 0.4785 × 5.0000 mm
# 单个体素体积: 1.1449 mm³
# 出血区域体素总数: 12668
# 出血体积: 14503.42 mm³ (14.503 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2875 mm
# 单个体素体积: 1.2606 mm³
# 出血区域体素总数: 592
# 出血体积: 746.30 mm³ (0.746 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0550 mm
# 单个体素体积: 1.2052 mm³
# 出血区域体素总数: 382
# 出血体积: 460.39 mm³ (0.460 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 18394
# 出血体积: 22512.28 mm³ (22.512 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0937 mm
# 单个体素体积: 1.2144 mm³
# 出血区域体素总数: 2283
# 出血体积: 2772.57 mm³ (2.773 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 24787
# 出血体积: 29548.41 mm³ (29.548 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.1774 mm
# 单个体素体积: 0.9960 mm³
# 出血区域体素总数: 735
# 出血体积: 732.03 mm³ (0.732 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4949 × 0.4949 × 5.0000 mm
# 单个体素体积: 1.2244 mm³
# 出血区域体素总数: 387
# 出血体积: 473.86 mm³ (0.474 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 6.0759 mm
# 单个体素体积: 1.4486 mm³
# 出血区域体素总数: 1651
# 出血体积: 2391.66 mm³ (2.392 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.3984 × 0.3984 × 5.0000 mm
# 单个体素体积: 0.7938 mm³
# 出血区域体素总数: 7563
# 出血体积: 6003.22 mm³ (6.003 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2013 mm
# 单个体素体积: 1.2401 mm³
# 出血区域体素总数: 334
# 出血体积: 414.19 mm³ (0.414 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.5059 × 0.5059 × 3.0000 mm
# 单个体素体积: 0.7677 mm³
# 出血区域体素总数: 52706
# 出血体积: 40461.40 mm³ (40.461 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 517
# 出血体积: 616.31 mm³ (0.616 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2150 mm
# 单个体素体积: 1.2433 mm³
# 出血区域体素总数: 4466
# 出血体积: 5552.77 mm³ (5.553 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3925 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 777
# 出血体积: 998.97 mm³ (0.999 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2427 mm
# 单个体素体积: 1.2500 mm³
# 出血区域体素总数: 2134
# 出血体积: 2667.43 mm³ (2.667 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4473 × 0.4473 × 5.0000 mm
# 单个体素体积: 1.0002 mm³
# 出血区域体素总数: 824
# 出血体积: 824.19 mm³ (0.824 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4949 × 0.4949 × 5.0000 mm
# 单个体素体积: 1.2244 mm³
# 出血区域体素总数: 41325
# 出血体积: 50600.27 mm³ (50.600 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.5566 × 0.5566 × 6.0000 mm
# 单个体素体积: 1.8591 mm³
# 出血区域体素总数: 18861
# 出血体积: 35064.35 mm³ (35.064 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 12528
# 出血体积: 14934.54 mm³ (14.935 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0935 mm
# 单个体素体积: 1.2144 mm³
# 出血区域体素总数: 10146
# 出血体积: 12321.18 mm³ (12.321 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2013 mm
# 单个体素体积: 1.2401 mm³
# 出血区域体素总数: 10053
# 出血体积: 12466.48 mm³ (12.466 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3507 mm
# 单个体素体积: 1.2757 mm³
# 出血区域体素总数: 65649
# 出血体积: 83749.26 mm³ (83.749 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 6.0000 mm
# 单个体素体积: 1.4305 mm³
# 出血区域体素总数: 2822
# 出血体积: 4036.90 mm³ (4.037 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0275 mm
# 单个体素体积: 1.1986 mm³
# 出血区域体素总数: 1500
# 出血体积: 1797.97 mm³ (1.798 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0852 mm
# 单个体素体积: 1.2124 mm³
# 出血区域体素总数: 5308
# 出血体积: 6435.48 mm³ (6.435 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 546
# 出血体积: 668.25 mm³ (0.668 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 31238
# 出血体积: 38231.96 mm³ (38.232 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0772 mm
# 单个体素体积: 1.2105 mm³
# 出血区域体素总数: 327
# 出血体积: 395.83 mm³ (0.396 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 11128
# 出血体积: 13265.60 mm³ (13.266 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1645 mm
# 单个体素体积: 1.2313 mm³
# 出血区域体素总数: 785
# 出血体积: 966.58 mm³ (0.967 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4949 × 0.4949 × 5.0000 mm
# 单个体素体积: 1.2244 mm³
# 出血区域体素总数: 10068
# 出血体积: 12327.73 mm³ (12.328 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2880 mm
# 单个体素体积: 1.2608 mm³
# 出血区域体素总数: 9215
# 出血体积: 11617.87 mm³ (11.618 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.0460 mm
# 单个体素体积: 0.9646 mm³
# 出血区域体素总数: 476
# 出血体积: 459.17 mm³ (0.459 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 3.9668 mm
# 单个体素体积: 0.9458 mm³
# 出血区域体素总数: 29825
# 出血体积: 28207.33 mm³ (28.207 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3925 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 1656
# 出血体积: 2129.08 mm³ (2.129 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4525 mm
# 单个体素体积: 1.3000 mm³
# 出血区域体素总数: 243
# 出血体积: 315.89 mm³ (0.316 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1887 mm
# 单个体素体积: 1.2371 mm³
# 出血区域体素总数: 138
# 出血体积: 170.72 mm³ (0.171 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4531 × 0.4531 × 5.0000 mm
# 单个体素体积: 1.0266 mm³
# 出血区域体素总数: 39829
# 出血体积: 40888.90 mm³ (40.889 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1004 mm
# 单个体素体积: 1.2160 mm³
# 出血区域体素总数: 944
# 出血体积: 1147.93 mm³ (1.148 cm³)
# 错误：掩码维度(512, 512, 37)与原图像维度(512, 512, 36)不一致！
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3210 mm
# 单个体素体积: 1.2686 mm³
# 出血区域体素总数: 8748
# 出血体积: 11097.86 mm³ (11.098 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4082 × 0.4082 × 5.0000 mm
# 单个体素体积: 0.8331 mm³
# 出血区域体素总数: 25324
# 出血体积: 21098.66 mm³ (21.099 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.2022 mm
# 单个体素体积: 1.0019 mm³
# 出血区域体素总数: 14960
# 出血体积: 14988.32 mm³ (14.988 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1004 mm
# 单个体素体积: 1.2160 mm³
# 出血区域体素总数: 283
# 出血体积: 344.14 mm³ (0.344 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0012 mm
# 单个体素体积: 1.1924 mm³
# 出血区域体素总数: 347
# 出血体积: 413.76 mm³ (0.414 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 195
# 出血体积: 232.46 mm³ (0.232 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4313 mm
# 单个体素体积: 1.2949 mm³
# 出血区域体素总数: 115
# 出血体积: 148.92 mm³ (0.149 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 3.7500 mm
# 单个体素体积: 0.8941 mm³
# 出血区域体素总数: 2836
# 出血体积: 2535.58 mm³ (2.536 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3925 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 5745
# 出血体积: 7386.20 mm³ (7.386 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1117 mm
# 单个体素体积: 1.2187 mm³
# 出血区域体素总数: 38353
# 出血体积: 46742.07 mm³ (46.742 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2147 mm
# 单个体素体积: 1.2433 mm³
# 出血区域体素总数: 7055
# 出血体积: 8771.41 mm³ (8.771 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.1131 mm
# 单个体素体积: 0.9806 mm³
# 出血区域体素总数: 4690
# 出血体积: 4599.18 mm³ (4.599 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4688 × 0.4688 × 5.0003 mm
# 单个体素体积: 1.0987 mm³
# 出血区域体素总数: 18191
# 出血体积: 19986.36 mm³ (19.986 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4707 × 0.4707 × 5.0000 mm
# 单个体素体积: 1.1078 mm³
# 出血区域体素总数: 1821
# 出血体积: 2017.32 mm³ (2.017 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.6381 mm
# 单个体素体积: 1.1058 mm³
# 出血区域体素总数: 29522
# 出血体积: 32645.64 mm³ (32.646 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3925 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 5022
# 出血体积: 6456.66 mm³ (6.457 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 8632
# 出血体积: 10290.15 mm³ (10.290 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3925 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 24263
# 出血体积: 31194.34 mm³ (31.194 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0918 mm
# 单个体素体积: 1.2140 mm³
# 出血区域体素总数: 1009
# 出血体积: 1224.91 mm³ (1.225 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3007 mm
# 单个体素体积: 1.2638 mm³
# 出血区域体素总数: 4784
# 出血体积: 6045.97 mm³ (6.046 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4949 × 0.4949 × 5.0000 mm
# 单个体素体积: 1.2244 mm³
# 出血区域体素总数: 609
# 出血体积: 745.69 mm³ (0.746 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.6692 mm
# 单个体素体积: 1.1132 mm³
# 出血区域体素总数: 11257
# 出血体积: 12531.45 mm³ (12.531 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.4359 mm
# 单个体素体积: 1.0576 mm³
# 出血区域体素总数: 2466
# 出血体积: 2608.05 mm³ (2.608 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 17773
# 出血体积: 21187.04 mm³ (21.187 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4947 mm
# 单个体素体积: 1.3100 mm³
# 出血区域体素总数: 1643
# 出血体积: 2152.41 mm³ (2.152 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.7696 mm
# 单个体素体积: 1.1372 mm³
# 出血区域体素总数: 860
# 出血体积: 977.96 mm³ (0.978 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 28121
# 出血体积: 33522.84 mm³ (33.523 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3925 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 69
# 出血体积: 88.71 mm³ (0.089 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3925 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 1882
# 出血体积: 2419.64 mm³ (2.420 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0150 mm
# 单个体素体积: 1.1957 mm³
# 出血区域体素总数: 4615
# 出血体积: 5518.05 mm³ (5.518 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4028 mm
# 单个体素体积: 1.2881 mm³
# 出血区域体素总数: 7065
# 出血体积: 9100.57 mm³ (9.101 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 1555
# 出血体积: 1853.71 mm³ (1.854 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 7516
# 出血体积: 8959.76 mm³ (8.960 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1025 mm
# 单个体素体积: 1.2165 mm³
# 出血区域体素总数: 6085
# 出血体积: 7402.60 mm³ (7.403 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0937 mm
# 单个体素体积: 1.2144 mm³
# 出血区域体素总数: 4362
# 出血体积: 5297.39 mm³ (5.297 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.1574 mm
# 单个体素体积: 0.9912 mm³
# 出血区域体素总数: 4959
# 出血体积: 4915.33 mm³ (4.915 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1657 mm
# 单个体素体积: 1.2316 mm³
# 出血区域体素总数: 639
# 出血体积: 786.99 mm³ (0.787 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.5504 mm
# 单个体素体积: 1.3233 mm³
# 出血区域体素总数: 54066
# 出血体积: 71547.17 mm³ (71.547 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4492 × 0.4492 × 5.0000 mm
# 单个体素体积: 1.0090 mm³
# 出血区域体素总数: 6549
# 出血体积: 6607.86 mm³ (6.608 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3001 mm
# 单个体素体积: 1.2637 mm³
# 出血区域体素总数: 30868
# 出血体积: 39006.46 mm³ (39.006 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.0438 mm
# 单个体素体积: 0.9641 mm³
# 出血区域体素总数: 12637
# 出血体积: 12183.67 mm³ (12.184 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4004 × 0.4004 × 5.0000 mm
# 单个体素体积: 0.8016 mm³
# 出血区域体素总数: 77
# 出血体积: 61.72 mm³ (0.062 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 2724
# 出血体积: 3247.26 mm³ (3.247 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# ...
# 出血体积: 4831.42 mm³ (4.831 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1117 mm
# 单个体素体积: 1.2187 mm³
# 出血区域体素总数: 37953
# 出血体积: 46254.58 mm³ (46.255 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.1821 mm
# 单个体素体积: 0.9971 mm³
# 出血区域体素总数: 1672
# 出血体积: 1667.14 mm³ (1.667 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3210 mm
# 单个体素体积: 1.2686 mm³
# 出血区域体素总数: 9895
# 出血体积: 12553.04 mm³ (12.553 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4733 mm
# 单个体素体积: 1.3049 mm³
# 出血区域体素总数: 10400
# 出血体积: 13571.22 mm³ (13.571 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1001 mm
# 单个体素体积: 1.2160 mm³
# 出血区域体素总数: 2872
# 出血体积: 3492.22 mm³ (3.492 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.4511 mm
# 单个体素体积: 1.0612 mm³
# 出血区域体素总数: 10318
# 出血体积: 10949.81 mm³ (10.950 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 6.0000 mm
# 单个体素体积: 1.4305 mm³
# 出血区域体素总数: 5451
# 出血体积: 7797.72 mm³ (7.798 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4937 mm
# 单个体素体积: 1.3098 mm³
# 出血区域体素总数: 1410
# 出血体积: 1846.82 mm³ (1.847 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 32254
# 出血体积: 39475.43 mm³ (39.475 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0631 mm
# 单个体素体积: 1.2071 mm³
# 出血区域体素总数: 4980
# 出血体积: 6011.51 mm³ (6.012 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 9283
# 出血体积: 11066.19 mm³ (11.066 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2427 mm
# 单个体素体积: 1.2500 mm³
# 出血区域体素总数: 1730
# 出血体积: 2162.44 mm³ (2.162 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0504 mm
# 单个体素体积: 1.2041 mm³
# 出血区域体素总数: 1262
# 出血体积: 1519.59 mm³ (1.520 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4733 mm
# 单个体素体积: 1.3049 mm³
# 出血区域体素总数: 6807
# 出血体积: 8882.63 mm³ (8.883 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 3.7500 mm
# 单个体素体积: 0.8941 mm³
# 出血区域体素总数: 10991
# 出血体积: 9826.71 mm³ (9.827 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 11782
# 出血体积: 14045.24 mm³ (14.045 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3925 mm
# 单个体素体积: 1.2857 mm³
# 出血区域体素总数: 6593
# 出血体积: 8476.45 mm³ (8.476 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4737 mm
# 单个体素体积: 1.3050 mm³
# 出血区域体素总数: 9620
# 出血体积: 12554.40 mm³ (12.554 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1117 mm
# 单个体素体积: 1.2187 mm³
# 出血区域体素总数: 24856
# 出血体积: 30292.83 mm³ (30.293 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4414 × 0.4414 × 5.0000 mm
# 单个体素体积: 0.9742 mm³
# 出血区域体素总数: 424
# 出血体积: 413.06 mm³ (0.413 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.5059 × 0.5059 × 5.0000 mm
# 单个体素体积: 1.2795 mm³
# 出血区域体素总数: 6686
# 出血体积: 8554.53 mm³ (8.555 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1765 mm
# 单个体素体积: 1.2342 mm³
# 出血区域体素总数: 13093
# 出血体积: 16158.97 mm³ (16.159 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1765 mm
# 单个体素体积: 1.2342 mm³
# 出血区域体素总数: 3134
# 出血体积: 3867.88 mm³ (3.868 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4434 × 0.4434 × 5.0000 mm
# 单个体素体积: 0.9828 mm³
# 出血区域体素总数: 3161
# 出血体积: 3106.75 mm³ (3.107 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.4120 mm
# 单个体素体积: 1.2903 mm³
# 出血区域体素总数: 19172
# 出血体积: 24738.02 mm³ (24.738 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 1798
# 出血体积: 2143.38 mm³ (2.143 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.5137 × 0.5137 × 6.2269 mm
# 单个体素体积: 1.6430 mm³
# 出血区域体素总数: 199
# 出血体积: 326.96 mm³ (0.327 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 6866
# 出血体积: 8184.91 mm³ (8.185 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4949 × 0.4949 × 5.0000 mm
# 单个体素体积: 1.2244 mm³
# 出血区域体素总数: 5924
# 出血体积: 7253.62 mm³ (7.254 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2880 mm
# 单个体素体积: 1.2608 mm³
# 出血区域体素总数: 4258
# 出血体积: 5368.30 mm³ (5.368 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4949 × 0.4949 × 5.0000 mm
# 单个体素体积: 1.2244 mm³
# 出血区域体素总数: 3907
# 出血体积: 4783.91 mm³ (4.784 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 812
# 出血体积: 967.98 mm³ (0.968 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.2443 mm
# 单个体素体积: 1.0119 mm³
# 出血区域体素总数: 926
# 出血体积: 937.04 mm³ (0.937 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4746 × 0.4746 × 5.0000 mm
# 单个体素体积: 1.1263 mm³
# 出血区域体素总数: 2012
# 出血体积: 2266.06 mm³ (2.266 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 7345
# 出血体积: 8755.92 mm³ (8.756 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4727 × 0.4727 × 5.0000 mm
# 单个体素体积: 1.1170 mm³
# 出血区域体素总数: 409
# 出血体积: 456.86 mm³ (0.457 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.3109 mm
# 单个体素体积: 1.2662 mm³
# 出血区域体素总数: 8195
# 出血体积: 10376.65 mm³ (10.377 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.2005 mm
# 单个体素体积: 1.2399 mm³
# 出血区域体素总数: 21506
# 出血体积: 26665.09 mm³ (26.665 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1763 mm
# 单个体素体积: 1.2341 mm³
# 出血区域体素总数: 7728
# 出血体积: 9537.25 mm³ (9.537 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 3089
# 出血体积: 3682.38 mm³ (3.682 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 4.9758 mm
# 单个体素体积: 1.1863 mm³
# 出血区域体素总数: 16808
# 出血体积: 19939.60 mm³ (19.940 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1530 mm
# 单个体素体积: 1.2286 mm³
# 出血区域体素总数: 10188
# 出血体积: 12516.67 mm³ (12.517 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 8152
# 出血体积: 9717.93 mm³ (9.718 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4948 × 0.4948 × 5.0000 mm
# 单个体素体积: 1.2239 mm³
# 出血区域体素总数: 14229
# 出血体积: 17414.77 mm³ (17.415 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.6004 mm
# 单个体素体积: 1.3352 mm³
# 出血区域体素总数: 39122
# 出血体积: 52237.22 mm³ (52.237 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.1007 mm
# 单个体素体积: 1.2161 mm³
# 出血区域体素总数: 7693
# 出血体积: 9355.45 mm³ (9.355 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4531 × 0.4531 × 6.3763 mm
# 单个体素体积: 1.3092 mm³
# 出血区域体素总数: 1131
# 出血体积: 1480.70 mm³ (1.481 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4668 × 0.4668 × 5.0000 mm
# 单个体素体积: 1.0895 mm³
# 出血区域体素总数: 17968
# 出血体积: 19576.07 mm³ (19.576 cm³)
# ============================================================
# 出血体积计算结果：
# ============================================================
# 单个体素尺寸 (x, y, z): 0.4883 × 0.4883 × 5.0000 mm
# 单个体素体积: 1.1921 mm³
# 出血区域体素总数: 3304
# 出血体积: 3938.67 mm³ (3.939 cm³)
# [{'file_name': '93dde5f0a1.nii.gz', 'hemorrhage_volume_cm3': np.float32(0.59952575)}, {'file_name': '416d908876.nii.gz', 'hemorrhage_volume_cm3': np.float32(2.0883648)}, {'file_name': '62ac06d17d.nii.gz', 'hemorrhage_volume_cm3': np.float32(6.4800215)}, {'file_name': '938c4efd14.nii.gz', 'hemorrhage_volume_cm3': np.float32(5.6480713)}, {'file_name': '3352a0291d.nii.gz', 'hemorrhage_volume_cm3': np.float32(2.127929)}, {'file_name': '07223e2a2d.nii.gz', 'hemorrhage_volume_cm3': np.float32(9.1103)}, {'file_name': '6b604a8156.nii.gz', 'hemorrhage_volume_cm3': np.float32(18.090494)}, {'file_name': '2166ee32e6.nii.gz', 'hemorrhage_volume_cm3': np.float32(2.7782617)}, {'file_name': '1139dc270b.nii.gz', 'hemorrhage_volume_cm3': np.float32(0.2819247)}, {'file_name': 'f1ac06a042.nii.gz', 'hemorrhage_volume_cm3': np.float32(38.03586)}, {'file_name': '39b6792a75.nii.gz', 'hemorrhage_volume_cm3': np.float32(8.470668)}, {'file_name': '4475b96ccd.nii.gz', 'hemorrhage_volume_cm3': np.float32(12.473877)}, {'file_name': '6909e9ec97.nii.gz', 'hemorrhage_volume_cm3': np.float32(16.057861)}, {'file_name': '210791b6f9.nii.gz', 'hemorrhage_volume_cm3': np.float32(0.5589992)}, {'file_name': '5f8255bf40.nii.gz', 'hemorrhage_volume_cm3': np.float32(0.5257905)}, {'file_name': '02e8d2742f.nii.gz', 'hemorrhage_volume_cm3': np.float32(9.474754)}, {'file_name': '6423ea8c07.nii.gz', 'hemorrhage_volume_cm3': np.float32(19.83289)}, {'file_name': '695fb1509f.nii.gz', 'hemorrhage_volume_cm3': np.float32(1.3407695)}, {'file_name': '6760aa4363.nii.gz', 'hemorrhage_volume_cm3': np.float32(66.09561)}, {'file_name': '609847bfe2.nii.gz', 'hemorrhage_volume_cm3': np.float32(0.52803296)}, {'file_name': '4ce3b6957a.nii.gz', 'hemorrhage_volume_cm3': np.float32(0.749429)}, {'file_name': '7a569b3064.nii.gz', 'hemorrhage_volume_cm3': np.float32(39.166504)}, {'file_name': '1cd202a3cc.nii.gz', 'hemorrhage_volume_cm3': np.float32(19.848118)}, {'file_name': 'eb6ac657a6.nii.gz', 'hemorrhage_volume_cm3': np.float32(34.792824)}, {'file_name': '8045cc444b.nii.gz', 'hemorrhage_volume_cm3': np.float32(7.268661)}, {'file_name': 'a43ad2b9ac.nii.gz', 'hemorrhage_volume_cm3': np.float32(46.26092)}, {'file_name': '6270e85cb5.nii.gz', 'hemorrhage_volume_cm3': np.float32(3.2646866)}, {'file_name': '102415070c.nii.gz', 'hemorrhage_volume_cm3': np.float32(22.30712)}, {'file_name': 'ff81fa79d6.nii.gz', 'hemorrhage_volume_cm3': np.float32(0.14675017)}, {'file_name': '08154d6b7b.nii.gz', 'hemorrhage_volume_cm3': np.float32(41.74586)}, {'file_name': '6cbe1f0a09.nii.gz', 'hemorrhage_volume_cm3': np.float32(4.3392587)}, {'file_name': '16ea2bcef7.nii.gz', 'hemorrhage_volume_cm3': np.float32(0.316276)}, {'file_name': '42bf1281ff.nii.gz', 'hemorrhage_volume_cm3': np.float32(9.098866)}, {'file_name': '105ec70b1d.nii.gz', 'hemorrhage_volume_cm3': np.float32(75.61332)}, {'file_name': '718c0188ef.nii.gz', 'hemorrhage_volume_cm3': np.float32(0.626767)}, {'file_name': '02a2bd8cc2.nii.gz', 'hemorrhage_volume_cm3': np.float32(18.606623)}, {'file_name': '72b5b93699.nii.gz', 'hemorrhage_volume_cm3': np.float32(20.078959)}, {'file_name': '6ef07e1c45.nii.gz', 'hemorrhage_volume_cm3': np.float32(3.48398)}, {'file_name': '7a2902d550.nii.gz', 'hemorrhage_volume_cm3': np.float32(0.3027916)}, {'file_name': '128d656c66.nii.gz', 'hemorrhage_volume_cm3': np.float32(1.8359513)}, {'file_name': '2c3307a4db.nii.gz', 'hemorrhage_volume_cm3': np.float32(5.0713253)}, {'file_name': 'bf7891541c.nii.gz', 'hemorrhage_volume_cm3': np.float32(2.3587651)}, {'file_name': '03e92a47d9.nii.gz', 'hemorrhage_volume_cm3': np.float32(12.565839)}, {'file_name': '6b37836125.nii.gz', 'hemorrhage_volume_cm3': np.float32(31.400846)}, {'file_name': '58afb7977e.nii.gz', 'hemorrhage_volume_cm3': np.float32(4.849215)}, {'file_name': '460d720b3f.nii.gz', 'hemorrhage_volume_cm3': np.float32(5.9091463)}, {'file_name': '6ff047baa3.nii.gz', 'hemorrhage_volume_cm3': np.float32(25.256397)}, {'file_name': '5b4b26aabb.nii.gz', 'hemorrhage_volume_cm3': np.float3 ...
# ✅ 数据已成功保存到CSV文件：hemorrhage_volume.csv
# 📊 数据总行数：526
# ⚠️  缺失值数量：1
